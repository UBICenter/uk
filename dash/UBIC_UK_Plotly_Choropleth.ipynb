# %%
# # install correct version of plotly
# !pip install plotly==4.13.0
# # Important library for many geopython libraries
# !apt install gdal-bin python-gdal python3-gdal 
# # Install rtree - Geopandas requirment
# !apt install python3-rtree 
# # Install Geopandas
# !pip install git+git://github.com/geopandas/geopandas.git
# # Install descartes - Geopandas requirment
# !pip install descartes 
# # Install Folium for Geographic data visualization
# !pip install folium
# # Install plotlyExpress
# !pip install plotly_express
# # Install contextily to make our map
# !pip install contextily

# !pip install plotly-geo==1.0.0
# !pip install dash==1.17.0

# import contextily as ctx
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
import matplotlib
import matplotlib.pyplot as plt 
import folium

# plotly
import plotly_express as px
import plotly.graph_objects as go
# from plotly import graph_objects as go



# geojson must be unwound before plotting
import json
# !pip install geojson_rewind
from geojson_rewind import rewind

# %% [markdown]
# # UK

# %%
baseline_file="https://raw.githubusercontent.com/fedderw/uk-ubi-regional-maps/main/baseline_regions.csv"
ubi_file="https://raw.githubusercontent.com/fedderw/uk-ubi-regional-maps/main/ubi_regions.csv"
region_geojson = "https://raw.githubusercontent.com/fedderw/uk-ubi-regional-maps/main/uk_regions.geojson"

# %%
def import_uk_region_boundaries():
  region_geojson = "https://raw.githubusercontent.com/fedderw/uk-ubi-regional-maps/main/uk_regions.geojson"
  # read geojson file as GeoPandas GeoDataframe
  gdf = gpd.read_file(region_geojson)
  # create dict that maps region names from ubi file to correspond with gdf
  region_name_dict = {'North East' : 'NORTH_EAST',
 'North West' : 'NORTH_WEST',
 'Yorkshire and the Humber' : 'YORKSHIRE',
 'East Midlands' : 'EAST_MIDLANDS',
 'West Midlands' : 'WEST_MIDLANDS',
 'East' : 'EAST_OF_ENGLAND',
 'London' : 'LONDON',
 'South East' : 'SOUTH_EAST',
 'South West' : 'SOUTH_WEST',
 'Northern Ireland' : 'NORTHERN_IRELAND',
 'Scotland' : 'SCOTLAND',
 'Wales' : 'WALES'}
  # replace values in col using above dict
  gdf.replace({'rgn19nm':region_name_dict},inplace=True)

  # change column name to match ubi col
  gdf.rename({'rgn19nm':'region_name'},axis=1,inplace=True)

  # set index to region name
  gdf.set_index('region_name',inplace=True)

  return gdf

# assign GeoDataFrame to regions
regions = import_uk_region_boundaries()
regions.head()
# Out:
#                objectid    rgn19cd   bng_e   bng_n     long        lat  \
# region_name
# NORTH_EAST            1  E12000001  417314  600356 -1.72888  55.297009
# NORTH_WEST            2  E12000002  350014  506279 -2.77239  54.449440
# YORKSHIRE             3  E12000003  446902  448736 -1.28714  53.932640
# EAST_MIDLANDS         4  E12000004  477659  322635 -0.84969  52.795719
# WEST_MIDLANDS         5  E12000005  386294  295477 -2.20358  52.556969
#
#                st_areashape  st_lengthshape ctry19nmw  \
# region_name
# NORTH_EAST     8.597298e+09    1.032344e+06      None
# NORTH_WEST     1.416487e+10    2.387418e+06      None
# YORKSHIRE      1.540842e+10    1.392569e+06      None
# EAST_MIDLANDS  1.564504e+10    1.388752e+06      None
# WEST_MIDLANDS  1.300374e+10    9.537750e+05      None
#
#                                                         geometry
# region_name
# NORTH_EAST     MULTIPOLYGON (((-2.03000 55.77000, -2.02000 55...
# NORTH_WEST     MULTIPOLYGON (((-2.53000 55.08000, -2.69000 55...
# YORKSHIRE      MULTIPOLYGON (((-0.79000 54.56000, -0.80000 54...
# EAST_MIDLANDS  MULTIPOLYGON (((-0.30000 53.61000, -0.31000 53...
# WEST_MIDLANDS  POLYGON ((-1.96000 53.22000, -1.98000 53.22000...

# %%
# use geopandas default ploting tool to check shape
regions.plot()

# %%
def import_grouped_region(url):
  # import grouped data before ubi simulation is run
  data = pd.read_csv(url)
  # use the unique region name as index
  data.set_index('region_name', inplace=True)
  return data

# %% [markdown]
# # Import Nikhil's ubi_regions data

# %%
def import_grouped_region_gdf(url):
  # import grouped data before ubi simulation is run
  data = pd.read_csv(url)
  # use the unique region name as index
  data.set_index('region_name', inplace=True)
  
  # merge geometry and region ID onto dataframe
  merged_gdf = gpd.GeoDataFrame(
      data.merge(
      regions[['rgn19cd','geometry']],
      how='left',
      left_index=True,
      right_index=True
      ),crs=regions.crs
    )
  return merged_gdf

# %%
# import file for full ubi+dis
ubi = import_grouped_region_gdf(ubi_file)
# import file for baseline
baseline = import_grouped_region_gdf(baseline_file)

# %%
ubi.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 12 entries, EAST_MIDLANDS to YORKSHIRE
# Data columns (total 32 columns):
# adults_in_household                12 non-null float64
# children_in_household              12 non-null float64
# country                            12 non-null int64
# household_equivalisation_ahc       12 non-null float64
# household_equivalisation_bhc       12 non-null float64
# household_id                       12 non-null float64
# household_weight                   12 non-null float64
# in_poverty_ahc                     12 non-null float64
# in_poverty_bhc                     12 non-null float64
# people_in_household                12 non-null float64
# region                             12 non-null float64
# seniors_in_household               12 non-null float64
# working_age_adults_in_household    12 non-null float64
# council_tax                        12 non-null float64
# housing_costs                      12 non-null float64
# housing_type                       12 non-null int64
# is_rented                          12 non-null float64
# is_shared                          12 non-null float64
# is_social                          12 non-null float64
# mortgage                           12 non-null float64
# num_rooms                          12 non-null float64
# rent                               12 non-null float64
# weekly_rent                        12 non-null float64
# equiv_household_net_income         12 non-null float64
# equiv_household_net_income_ahc     12 non-null float64
# household_earnings                 12 non-null float64
# household_income                   12 non-null float64
# household_net_income               12 non-null float64
# household_net_income_ahc           12 non-null float64
# household_basic_income             12 non-null float64
# rgn19cd                            12 non-null object
# geometry                           12 non-null geometry
# dtypes: float64(28), geometry(1), int64(2), object(1)
# memory usage: 3.4+ KB

# %%
baseline.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 12 entries, EAST_MIDLANDS to YORKSHIRE
# Data columns (total 31 columns):
# adults_in_household                12 non-null float64
# children_in_household              12 non-null float64
# country                            12 non-null int64
# household_equivalisation_ahc       12 non-null float64
# household_equivalisation_bhc       12 non-null float64
# household_id                       12 non-null float64
# household_weight                   12 non-null float64
# in_poverty_ahc                     12 non-null float64
# in_poverty_bhc                     12 non-null float64
# people_in_household                12 non-null float64
# region                             12 non-null float64
# seniors_in_household               12 non-null float64
# working_age_adults_in_household    12 non-null float64
# council_tax                        12 non-null float64
# housing_costs                      12 non-null float64
# housing_type                       12 non-null int64
# is_rented                          12 non-null float64
# is_shared                          12 non-null float64
# is_social                          12 non-null float64
# mortgage                           12 non-null float64
# num_rooms                          12 non-null float64
# rent                               12 non-null float64
# weekly_rent                        12 non-null float64
# equiv_household_net_income         12 non-null float64
# equiv_household_net_income_ahc     12 non-null float64
# household_earnings                 12 non-null float64
# household_income                   12 non-null float64
# household_net_income               12 non-null float64
# household_net_income_ahc           12 non-null float64
# rgn19cd                            12 non-null object
# geometry                           12 non-null geometry
# dtypes: float64(27), geometry(1), int64(2), object(1)
# memory usage: 3.3+ KB

# %%
baseline.head().T
# Out:
# region_name                                                          EAST_MIDLANDS  \
# adults_in_household                                                        1.76516
# children_in_household                                                     0.526439
# country                                                                          0
# household_equivalisation_ahc                                              0.945334
# household_equivalisation_bhc                                              0.975078
# household_id                                                           1.09734e+06
# household_weight                                                           1556.18
# in_poverty_ahc                                                             0.18818
# in_poverty_bhc                                                             0.16563
# people_in_household                                                         2.2916
# region                                                                           3
# seniors_in_household                                                      0.504666
# working_age_adults_in_household                                             1.2675
# council_tax                                                                1407.41
# housing_costs                                                              60.2815
# housing_type                                                                     1
# is_rented                                                                        0
# is_shared                                                               0.00933126
# is_social                                                                 0.181182
# mortgage                                                                         0
# num_rooms                                                                  5.61975
# rent                                                                       36.8515
# weekly_rent                                                                      0
# equiv_household_net_income                                                 31928.7
# equiv_household_net_income_ahc                                             30272.8
# household_earnings                                                         26490.7
# household_income                                                           35606.8
# household_net_income                                                       30872.1
# household_net_income_ahc                                                   27895.2
# rgn19cd                                                                  E12000004
# geometry                         (POLYGON ((-0.3 53.61, -0.31 53.61, -0.3 53.61...
#
# region_name                                                        EAST_OF_ENGLAND  \
# adults_in_household                                                         1.7635
# children_in_household                                                     0.485413
# country                                                                          0
# household_equivalisation_ahc                                              0.934413
# household_equivalisation_bhc                                              0.964749
# household_id                                                           1.09643e+06
# household_weight                                                           1599.68
# in_poverty_ahc                                                            0.170701
# in_poverty_bhc                                                             0.13532
# people_in_household                                                        2.24891
# region                                                                           5
# seniors_in_household                                                      0.546245
# working_age_adults_in_household                                            1.22719
# council_tax                                                                1554.06
# housing_costs                                                              75.9621
# housing_type                                                                     1
# is_rented                                                                        0
# is_shared                                                               0.00496586
# is_social                                                                 0.162632
# mortgage                                                                         0
# num_rooms                                                                  5.54066
# rent                                                                       43.4643
# weekly_rent                                                                      0
# equiv_household_net_income                                                 35538.3
# equiv_household_net_income_ahc                                             33189.8
# household_earnings                                                         31410.2
# household_income                                                           41600.9
# household_net_income                                                       33826.3
# household_net_income_ahc                                                   29950.5
# rgn19cd                                                                  E12000006
# geometry                         (POLYGON ((1 52.98, 0.99 52.98, 0.98 52.98, 0....
#
# region_name                                                                 LONDON  \
# adults_in_household                                                        1.88008
# children_in_household                                                     0.675048
# country                                                                          0
# household_equivalisation_ahc                                              0.941741
# household_equivalisation_bhc                                              0.977601
# household_id                                                            1.0952e+06
# household_weight                                                           2268.67
# in_poverty_ahc                                                            0.294004
# in_poverty_bhc                                                            0.176015
# people_in_household                                                        2.55513
# region                                                                           6
# seniors_in_household                                                      0.349452
# working_age_adults_in_household                                            1.54997
# council_tax                                                                1599.57
# housing_costs                                                              154.001
# housing_type                                                                     1
# is_rented                                                                        0
# is_shared                                                                0.0141844
# is_social                                                                 0.256609
# mortgage                                                                         0
# num_rooms                                                                  4.64217
# rent                                                                       115.068
# weekly_rent                                                                      0
# equiv_household_net_income                                                 42157.6
# equiv_household_net_income_ahc                                             36858.8
# household_earnings                                                         44744.9
# household_income                                                           51136.6
# household_net_income                                                       39761.3
# household_net_income_ahc                                                   32384.1
# rgn19cd                                                                  E12000007
# geometry                         (POLYGON ((0.02 51.64, -0.19 51.67, -0.2 51.67...
#
# region_name                                                       NORTHERN_IRELAND  \
# adults_in_household                                                        1.70203
# children_in_household                                                     0.553297
# country                                                                          0
# household_equivalisation_ahc                                              0.928052
# household_equivalisation_bhc                                              0.962231
# household_id                                                           1.09726e+06
# household_weight                                                           363.697
# in_poverty_ahc                                                            0.147248
# in_poverty_bhc                                                            0.143778
# people_in_household                                                        2.25533
# region                                                                          11
# seniors_in_household                                                      0.452157
# working_age_adults_in_household                                             1.2707
# council_tax                                                                      0
# housing_costs                                                              43.7809
# housing_type                                                                     1
# is_rented                                                                        0
# is_shared                                                               0.00594943
# is_social                                                                 0.164105
# mortgage                                                                         0
# num_rooms                                                                  5.91869
# rent                                                                       31.0104
# weekly_rent                                                                      0
# equiv_household_net_income                                                 30755.3
# equiv_household_net_income_ahc                                             29987.8
# household_earnings                                                         22867.3
# household_income                                                           29699.1
# household_net_income                                                       29147.2
# household_net_income_ahc                                                   26905.5
# rgn19cd                                                                  N92000002
# geometry                         (POLYGON ((-6.48 55.25, -6.49 55.25, -6.48 55....
#
# region_name                                                             NORTH_EAST
# adults_in_household                                                        1.67179
# children_in_household                                                     0.512821
# country                                                                          0
# household_equivalisation_ahc                                              0.904359
# household_equivalisation_bhc                                              0.941282
# household_id                                                           1.09357e+06
# household_weight                                                           1489.42
# in_poverty_ahc                                                            0.217949
# in_poverty_bhc                                                            0.182051
# people_in_household                                                        2.18462
# region                                                                           0
# seniors_in_household                                                      0.475641
# working_age_adults_in_household                                            1.20769
# council_tax                                                                1273.24
# housing_costs                                                              59.7359
# housing_type                                                                     1
# is_rented                                                                        0
# is_shared                                                               0.00512821
# is_social                                                                 0.248718
# mortgage                                                                         0
# num_rooms                                                                  5.34615
# rent                                                                       37.9641
# weekly_rent                                                                      0
# equiv_household_net_income                                                 29460.4
# equiv_household_net_income_ahc                                             27745.4
# household_earnings                                                         21515.5
# household_income                                                           29318.3
# household_net_income                                                         27326
# household_net_income_ahc                                                   24316.8
# rgn19cd                                                                  E12000001
# geometry                         (POLYGON ((-2.03 55.77, -2.02 55.77, -2.03 55....

# %% [markdown]
# I wasn't sure which columns where relevent, so here looked for columns with values that changed between the two files and added those columns to a list

# %%
def diff_cols(df,region="EAST_MIDLANDS"):
    """
    Identify which columns are changing in df from baseline
    
    args:
        region: of uk to use as an example
        
    
    """
    # init empty list for
    diff_cols = []

    # figure out which columns' values change between the two dataframes
    for col in df.select_dtypes(['int','float']).columns:
      if col in baseline.select_dtypes(['int','float']).columns:
        df_region = df.loc[region,col]
        baseline_region = baseline.loc[region,col]
        diff = df_region-baseline_region
        if diff!=0:
          diff_cols.append(col)
#       print(str(col)+": "+str(diff))
    
    return diff_cols

# %%
def rel_change_reform(data, cols=[], * args):
  '''this function calculates the relative change between specified columns
   from one simulation to the baseline and returns a GeoDataFrame object
   that includes all columns in input dataframe + new columns
  with relative changes'''
  newgdf = data.copy(deep=True)
  for col in cols:
    # name new string
    pct_change_string = str(col)+"_pct_change"
    net_change_string = str(col)+"_net_change"
    newgdf[pct_change_string] = (newgdf[col]-baseline[col])/baseline[col]*100
    newgdf[net_change_string] = newgdf[col]-baseline[col]
  return newgdf

# rel_change_reform(ubi, diff_cols)

# %%
full_dis = rel_change_reform(ubi, diff_cols(ubi))
full_dis.head().T
# Out:
# region_name                                                                    EAST_MIDLANDS  \
# adults_in_household                                                                  1.76516
# children_in_household                                                               0.526439
# country                                                                                    0
# household_equivalisation_ahc                                                        0.945334
# household_equivalisation_bhc                                                        0.975078
# household_id                                                                     1.09734e+06
# household_weight                                                                     1556.18
# in_poverty_ahc                                                                     0.0902022
# in_poverty_bhc                                                                     0.0979782
# people_in_household                                                                   2.2916
# region                                                                                     3
# seniors_in_household                                                                0.501555
# working_age_adults_in_household                                                       1.2675
# council_tax                                                                          1407.41
# housing_costs                                                                        60.2815
# housing_type                                                                               1
# is_rented                                                                                  0
# is_shared                                                                         0.00933126
# is_social                                                                           0.181182
# mortgage                                                                                   0
# num_rooms                                                                            5.61975
# rent                                                                                 36.8515
# weekly_rent                                                                                0
# equiv_household_net_income                                                             31476
# equiv_household_net_income_ahc                                                       29537.2
# household_earnings                                                                   26490.7
# household_income                                                                       31882
# household_net_income                                                                 31016.3
# household_net_income_ahc                                                             27902.1
# household_basic_income                                                               281.435
# rgn19cd                                                                            E12000004
# geometry                                   (POLYGON ((-0.3 53.61, -0.31 53.61, -0.3 53.61...
# in_poverty_ahc_pct_change                                                           -52.0661
# in_poverty_ahc_net_change                                                         -0.0979782
# in_poverty_bhc_pct_change                                                           -40.8451
# in_poverty_bhc_net_change                                                         -0.0676516
# seniors_in_household_pct_change                                                    -0.616333
# seniors_in_household_net_change                                                  -0.00311042
# equiv_household_net_income_pct_change                                               -1.41783
# equiv_household_net_income_net_change                                               -452.693
# equiv_household_net_income_ahc_pct_change                                           -2.42981
# equiv_household_net_income_ahc_net_change                                           -735.572
# household_income_pct_change                                                         -10.4609
# household_income_net_change                                                          -3724.8
# household_net_income_pct_change                                                     0.467099
# household_net_income_net_change                                                      144.203
# household_net_income_ahc_pct_change                                                0.0246064
# household_net_income_ahc_net_change                                                    6.864
#
# region_name                                                                  EAST_OF_ENGLAND  \
# adults_in_household                                                                   1.7635
# children_in_household                                                               0.485413
# country                                                                                    0
# household_equivalisation_ahc                                                        0.934413
# household_equivalisation_bhc                                                        0.964749
# household_id                                                                     1.09643e+06
# household_weight                                                                     1599.68
# in_poverty_ahc                                                                     0.0924891
# in_poverty_bhc                                                                     0.0856611
# people_in_household                                                                  2.24891
# region                                                                                     5
# seniors_in_household                                                                0.543762
# working_age_adults_in_household                                                      1.22719
# council_tax                                                                          1554.06
# housing_costs                                                                        75.9621
# housing_type                                                                               1
# is_rented                                                                                  0
# is_shared                                                                         0.00496586
# is_social                                                                           0.162632
# mortgage                                                                                   0
# num_rooms                                                                            5.54066
# rent                                                                                 43.4643
# weekly_rent                                                                                0
# equiv_household_net_income                                                           34265.8
# equiv_household_net_income_ahc                                                       31697.9
# household_earnings                                                                   31410.2
# household_income                                                                     37668.2
# household_net_income                                                                 33325.7
# household_net_income_ahc                                                             29397.4
# household_basic_income                                                               279.035
# rgn19cd                                                                            E12000006
# geometry                                   (POLYGON ((1 52.98, 0.99 52.98, 0.98 52.98, 0....
# in_poverty_ahc_pct_change                                                           -45.8182
# in_poverty_ahc_net_change                                                         -0.0782123
# in_poverty_bhc_pct_change                                                           -36.6972
# in_poverty_bhc_net_change                                                         -0.0496586
# seniors_in_household_pct_change                                                    -0.454545
# seniors_in_household_net_change                                                  -0.00248293
# equiv_household_net_income_pct_change                                                -3.5804
# equiv_household_net_income_net_change                                               -1272.41
# equiv_household_net_income_ahc_pct_change                                           -4.49507
# equiv_household_net_income_ahc_net_change                                           -1491.91
# household_income_pct_change                                                         -9.45322
# household_income_net_change                                                         -3932.62
# household_net_income_pct_change                                                     -1.47977
# household_net_income_net_change                                                     -500.551
# household_net_income_ahc_pct_change                                                 -1.84665
# household_net_income_ahc_net_change                                                  -553.08
#
# region_name                                                                           LONDON  \
# adults_in_household                                                                  1.88008
# children_in_household                                                               0.675048
# country                                                                                    0
# household_equivalisation_ahc                                                        0.941741
# household_equivalisation_bhc                                                        0.977601
# household_id                                                                      1.0952e+06
# household_weight                                                                     2268.67
# in_poverty_ahc                                                                      0.168279
# in_poverty_bhc                                                                      0.110896
# people_in_household                                                                  2.55513
# region                                                                                     6
# seniors_in_household                                                                0.348807
# working_age_adults_in_household                                                      1.54997
# council_tax                                                                          1599.57
# housing_costs                                                                        154.001
# housing_type                                                                               1
# is_rented                                                                                  0
# is_shared                                                                          0.0141844
# is_social                                                                           0.256609
# mortgage                                                                                   0
# num_rooms                                                                            4.64217
# rent                                                                                 115.068
# weekly_rent                                                                                0
# equiv_household_net_income                                                           41817.7
# equiv_household_net_income_ahc                                                       35981.8
# household_earnings                                                                   44744.9
# household_income                                                                     48651.9
# household_net_income                                                                 40440.3
# household_net_income_ahc                                                             32769.1
# household_basic_income                                                               298.477
# rgn19cd                                                                            E12000007
# geometry                                   (POLYGON ((0.02 51.64, -0.19 51.67, -0.2 51.67...
# in_poverty_ahc_pct_change                                                           -42.7632
# in_poverty_ahc_net_change                                                          -0.125725
# in_poverty_bhc_pct_change                                                           -36.9963
# in_poverty_bhc_net_change                                                         -0.0651193
# seniors_in_household_pct_change                                                    -0.184502
# seniors_in_household_net_change                                                 -0.000644745
# equiv_household_net_income_pct_change                                              -0.806204
# equiv_household_net_income_net_change                                               -339.876
# equiv_household_net_income_ahc_pct_change                                           -2.37934
# equiv_household_net_income_ahc_net_change                                           -876.996
# household_income_pct_change                                                         -4.85888
# household_income_net_change                                                         -2484.67
# household_net_income_pct_change                                                      1.70765
# household_net_income_net_change                                                      678.983
# household_net_income_ahc_pct_change                                                  1.18882
# household_net_income_ahc_net_change                                                   384.99
#
# region_name                                                                 NORTHERN_IRELAND  \
# adults_in_household                                                                  1.70203
# children_in_household                                                               0.553297
# country                                                                                    0
# household_equivalisation_ahc                                                        0.928052
# household_equivalisation_bhc                                                        0.962231
# household_id                                                                     1.09726e+06
# household_weight                                                                     363.697
# in_poverty_ahc                                                                     0.0505702
# in_poverty_bhc                                                                     0.0614774
# people_in_household                                                                  2.25533
# region                                                                                    11
# seniors_in_household                                                                0.449678
# working_age_adults_in_household                                                       1.2707
# council_tax                                                                                0
# housing_costs                                                                        43.7809
# housing_type                                                                               1
# is_rented                                                                                  0
# is_shared                                                                         0.00594943
# is_social                                                                           0.164105
# mortgage                                                                                   0
# num_rooms                                                                            5.91869
# rent                                                                                 31.0104
# weekly_rent                                                                                0
# equiv_household_net_income                                                           31586.4
# equiv_household_net_income_ahc                                                       30767.9
# household_earnings                                                                   22867.3
# household_income                                                                     26461.7
# household_net_income                                                                 30543.7
# household_net_income_ahc                                                               28272
# household_basic_income                                                               277.498
# rgn19cd                                                                            N92000002
# geometry                                   (POLYGON ((-6.48 55.25, -6.49 55.25, -6.48 55....
# in_poverty_ahc_pct_change                                                           -65.6566
# in_poverty_ahc_net_change                                                         -0.0966782
# in_poverty_bhc_pct_change                                                           -57.2414
# in_poverty_bhc_net_change                                                         -0.0823004
# seniors_in_household_pct_change                                                    -0.548246
# seniors_in_household_net_change                                                  -0.00247893
# equiv_household_net_income_pct_change                                                2.70214
# equiv_household_net_income_net_change                                                 831.05
# equiv_household_net_income_ahc_pct_change                                            2.60152
# equiv_household_net_income_ahc_net_change                                            780.138
# household_income_pct_change                                                         -10.9005
# household_income_net_change                                                         -3237.36
# household_net_income_pct_change                                                      4.79125
# household_net_income_net_change                                                      1396.52
# household_net_income_ahc_pct_change                                                  5.07912
# household_net_income_ahc_net_change                                                  1366.56
#
# region_name                                                                       NORTH_EAST
# adults_in_household                                                                  1.67179
# children_in_household                                                               0.512821
# country                                                                                    0
# household_equivalisation_ahc                                                        0.904359
# household_equivalisation_bhc                                                        0.941282
# household_id                                                                     1.09357e+06
# household_weight                                                                     1489.42
# in_poverty_ahc                                                                      0.120513
# in_poverty_bhc                                                                       0.10641
# people_in_household                                                                  2.18462
# region                                                                                     0
# seniors_in_household                                                                0.471795
# working_age_adults_in_household                                                      1.20769
# council_tax                                                                          1273.24
# housing_costs                                                                        59.7359
# housing_type                                                                               1
# is_rented                                                                                  0
# is_shared                                                                         0.00512821
# is_social                                                                           0.248718
# mortgage                                                                                   0
# num_rooms                                                                            5.34615
# rent                                                                                 37.9641
# weekly_rent                                                                                0
# equiv_household_net_income                                                           29604.1
# equiv_household_net_income_ahc                                                       27737.3
# household_earnings                                                                   21515.5
# household_income                                                                       25804
# household_net_income                                                                 28021.4
# household_net_income_ahc                                                             24925.5
# household_basic_income                                                               267.139
# rgn19cd                                                                            E12000001
# geometry                                   (POLYGON ((-2.03 55.77, -2.02 55.77, -2.03 55....
# in_poverty_ahc_pct_change                                                           -44.7059
# in_poverty_ahc_net_change                                                         -0.0974359
# in_poverty_bhc_pct_change                                                           -41.5493
# in_poverty_bhc_net_change                                                          -0.075641
# seniors_in_household_pct_change                                                    -0.808625
# seniors_in_household_net_change                                                  -0.00384615
# equiv_household_net_income_pct_change                                               0.487783
# equiv_household_net_income_net_change                                                143.703
# equiv_household_net_income_ahc_pct_change                                         -0.0292949
# equiv_household_net_income_ahc_net_change                                             -8.128
# household_income_pct_change                                                         -11.9869
# household_income_net_change                                                         -3514.35
# household_net_income_pct_change                                                      2.54498
# household_net_income_net_change                                                       695.44
# household_net_income_ahc_pct_change                                                  2.50328
# household_net_income_ahc_net_change                                                  608.717

# %% [markdown]
# # Plotly Dropdown

# %%
import re

# %% [markdown]
# This cell currently works, I'll turn this into a function once I make some other changes.

# %%
cols_dd = list(full_dis.iloc[:,32:].columns)

in_poverty_cols = ['in_poverty_ahc_pct_change',
'in_poverty_ahc_net_change',
'in_poverty_bhc_pct_change',
'in_poverty_bhc_net_change']

# we need to add this to select which trace 
# is going to be visible
visible = np.array(cols_dd)

# define traces and buttons at once
# initialize empty lists
traces = []
buttons = []

#Populate regions['properties'] (i.e. convert to plotly-readible geojson-type)
regions_unwound = json.loads(regions.to_json())
# rewind the unwound geojson
regions_rewound = rewind(regions_unwound,rfc7946=False)

# for loop to interate through targeted columns
for value in cols_dd:
  # append object to traces
  traces.append(
      # create graph object
      go.Choropleth(
          # spatial coordinates ??
          locations=regions.index, 
          # geojson for boundaries
          geojson = regions_rewound,
          # data to color code
          z=full_dis[value].astype(float).round(2),
          # set title of color bar
          colorbar_title=value,
          # set color scale
          colorscale= "Viridis" if value in in_poverty_cols else "PiYG",
          # set midpoint of color scale value to be 0
          zmid= False if value in in_poverty_cols else 0,
          # color_continuous_scale=px.colors.diverging.RdBu,
          # colorscale_midpoint=0,
          # check if this variable is the first 
          # in the list to display by default.
          visible= True if value==cols_dd[0] else False,
          # hovertemplate = 'Average Income Change: %{z:£.2f}<extra></extra>'if re.match(r'income?.*abs?', value) else z
          ))
  
  # append dict objects to list of buttons
  buttons.append(
      dict(
          label=value,
          method="update",
          args=[{"visible":list(visible==value)},
                {"title":f"<b>{value}</b>"}])) # ??

# define updatemenus object
updatemenus = [{"active":0, # ??
                "buttons":buttons,
              }]

# now we define fig
fig = go.Figure(
    data=traces,
    layout=dict(updatemenus=updatemenus)
    )


# This is in order to get the first title displayed correctly
first_title = cols_dd[0]

# set projection type, turn off base map to just show regional boundaries
fig.update_geos(
      projection_type="mercator",
      fitbounds="locations",
      visible=False
  )

fig.update_layout(
      plot_bgcolor="#323130",
      # height=300,
      margin={"r":0,"t":0,"l":0,"b":0},
      title=f"<b>{first_title}</b>",
      title_x=0.5,
      title_y=0.05
      )  



# display figure
fig.show()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# ## Function

# %%
def dropdown_choropleth(data, columns=[]):
  # make list of columns for dropdown
  cols_dd = list(full_dis.iloc[:,32:].columns)

  in_poverty_cols = ['in_poverty_ahc_pct_change',
  'in_poverty_ahc_abs_change',
  'in_poverty_bhc_pct_change',
  'in_poverty_bhc_abs_change']

  # we need to add this to select which trace 
  # is going to be visible
  visible = np.array(cols_dd)

  # define traces and buttons at once
  # initialize empty lists
  traces = []
  buttons = []

  #Populate regions['properties'] (i.e. convert to plotly-readible geojson-type)
  regions_unwound = json.loads(regions.to_json())
  # rewind the unwound geojson
  regions_rewound = rewind(regions_unwound,rfc7946=False)

  # for loop to interate through targeted columns
  for value in cols_dd:
    # append object to traces
    traces.append(
        # create graph object
        go.Choropleth(
            # spatial coordinates ??
            locations=regions.index, 
            # geojson for boundaries
            geojson = regions_rewound,
            # data to color code
            z=full_dis[value].astype(float).round(2),
            # set title of color bar
            colorbar_title=value,
            # set color scale
            colorscale= "Viridis" if value in in_poverty_cols else "PiYG",
            # set midpoint of color scale value to be 0
            zmid= False if value in in_poverty_cols else 0,
            # color_continuous_scale=px.colors.diverging.RdBu,
            # colorscale_midpoint=0,
            # check if this variable is the first 
            # in the list to display by default.
            visible= True if value==cols_dd[0] else False,
            # hovertemplate = 'Average Income Change: %{z:£.2f}<extra></extra>'if re.match(r'income?.*abs?', value) else z
            ))
    
    # append dict objects to list of buttons
    buttons.append(
        dict(
            label=value,
            method="update",
            args=[{"visible":list(visible==value)},
                  {"title":f"<b>{value}</b>"}])) # ??

  # define updatemenus object
  updatemenus = [{"active":0, # ??
                  "buttons":buttons,
                }]

  # now we define fig
  fig = go.Figure(
      data=traces,
      layout=dict(updatemenus=updatemenus)
      )


  # This is in order to get the first title displayed correctly
  first_title = cols_dd[0]

  # set projection type, turn off base map to just show regional boundaries
  fig.update_geos(
        projection_type="mercator",
        fitbounds="locations",
        visible=False
    )

  fig.update_layout(
        plot_bgcolor="#323130",
        # height=300,
        margin={"r":0,"t":0,"l":0,"b":0},
        title=f"<b>{first_title}</b>",
        title_x=0.5,
        title_y=0.05
        )  



  # display figure
  fig.show()

# %% [markdown]
# # Dash

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash

# %%
# def echo(message=None, file=sys.stdout, nl=True, err=False, color=None):

# %%
# external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = JupyterDash(__name__)
# app = dash.Dash(__name__)

cols_dd = list(full_dis.iloc[:,32:].columns)

in_poverty_cols = ['in_poverty_ahc_pct_change',
'in_poverty_ahc_net_change',
'in_poverty_bhc_pct_change',
'in_poverty_bhc_net_change']

# we need to add this to select which trace 
# is going to be visible
visible = np.array(cols_dd)

# define traces and buttons at once
# initialize empty lists
traces = []
buttons = []

#Populate regions['properties'] (i.e. convert to plotly-readible geojson-type)
regions_unwound = json.loads(regions.to_json())
# rewind the unwound geojson
regions_rewound = rewind(regions_unwound,rfc7946=False)

# for loop to interate through targeted columns
for value in cols_dd:
  # append object to traces
  traces.append(
      # create graph object
      go.Choropleth(
          # spatial coordinates ??
          locations=regions.index, 
          # geojson for boundaries
          geojson = regions_rewound,
          # data to color code
          z=full_dis[value].astype(float).round(2),
          # set title of color bar
          colorbar_title=value,
          # set color scale
          colorscale= "Greens_r" if value in in_poverty_cols else "PiYG",
          # set midpoint of color scale value to be 0
          zmid= False if value in in_poverty_cols else 0,
          # color_continuous_scale=px.colors.diverging.RdBu,
          # colorscale_midpoint=0,
          # check if this variable is the first 
          # in the list to display by default.
          visible= True if value==cols_dd[0] else False,
          # hovertemplate = 'Average Income Change: %{z:£.2f}<extra></extra>'if re.match(r'income?.*abs?', value) else z
          ))
  
  # append dict objects to list of buttons
  buttons.append(
      dict(
          label=value,
          method="update",
          args=[{"visible":list(visible==value)},
                {"title":f"<b>{value}</b>"}])) # ??

# define updatemenus object
updatemenus = [{"active":0, # ??
                "buttons":buttons,
              }]

# now we define fig
fig = go.Figure(
    data=traces,
    layout=dict(updatemenus=updatemenus)
    )


# This is in order to get the first title displayed correctly
first_title = cols_dd[0]

# set projection type, turn off base map to just show regional boundaries
fig.update_geos(
      projection_type="mercator",
      fitbounds="locations",
      visible=False
  )

fig.update_layout(
      plot_bgcolor="#323130",
      # height=300,
      margin={"r":0,"t":0,"l":0,"b":0},
      title=f"<b>{first_title}</b>",
      title_x=0.5,
      title_y=0.05
      )  




# app = dash.Dash()
app.layout = html.Div([
    dcc.Graph(figure=fig)
])

# Run app and display result inline in the notebook
app.run_server(mode='inline',port=8060)

# if __name__ == '__main__':
#     app.run_server(debug=True,
#                    use_reloader=False,
#                    port=8060
#                   )

# app.run_server(debug=True, use_reloader=False)  # Turn off reloader if inside Jupyter
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8060/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
